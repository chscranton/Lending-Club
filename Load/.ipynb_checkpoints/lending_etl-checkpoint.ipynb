# %% [markdown]
# ### Dependencies

# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Connect to local database that  was created using the lending_db.sql file

# %%
rds_connection_string = "postgres:postgres@localhost:5432/lending_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %% [markdown]
# ### Check for tables

# %%
engine.table_names()
# Out:
# []

# %% [markdown]
# ### Store transformed CSV files in Dataframes

# %%
lending_csv_file = "../DataFiles/clean_data_final.csv.gz"
state_csv_file = "../DataFiles/combined_state_finance_data.csv"

lending_df = pd.read_csv(lending_csv_file, compression='gzip', index_col=False)
state_df = pd.read_csv(state_csv_file)

# %%
lending_df.head()
# Out:
#    id  loan_amnt  term  int_rate issue_date             purpose zip_code  \
# 0   0       2500    36     13.56    12-2018  debt_consolidation    109xx
# 1   1      30000    60     18.94    12-2018  debt_consolidation    713xx
# 2   2       5000    36     17.97    12-2018  debt_consolidation    490xx
# 3   3       4000    36     18.94    12-2018  debt_consolidation    985xx
# 4   4      30000    60     16.14    12-2018  debt_consolidation    212xx
#
#   state  annual_inc home_ownership
# 0    NY       55000           RENT
# 1    LA       90000       MORTGAGE
# 2    MI       59280       MORTGAGE
# 3    WA       92000       MORTGAGE
# 4    MD       57250       MORTGAGE

# %%
state_df.head()
# Out:
#         state abbreviation  population  average_income_2018  \
# 0     Alabama           AL      198218                49861
# 1      Alaska           AK       31275                74346
# 2     Arizona           AZ     1660272                59246
# 3    Arkansas           AR      193524                47062
# 4  California           CA      508529                75277
#
#    average_income_2017  average_income_2016  average_vantagescore  \
# 0                48123                46257                   654
# 1                73181                76440                   668
# 2                56581                53558                   669
# 3                45869                44334                   657
# 4                71805                67739                   680
#
#    average_credit_card_balance
# 0                         5961
# 1                         8516
# 2                         6389
# 3                         5660
# 4                         6481

# %% [markdown]
# ### Use pandas to load CSV converted DataFrames into database

# %%
lending_df.to_sql(name='lending_data', con=engine, if_exists='append', index=False)

# %%
state_df.to_sql(name='state_data', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm data has been added by querying the lending_data table

# %%
pd.read_sql_query('select * from lending_data', con=engine).head()
# Out:
#    id  loan_amnt  term  int_rate issue_date             purpose zip_code  \
# 0   0       2500    36     13.56    12-2018  debt_consolidation    109xx
# 1   1      30000    60     18.94    12-2018  debt_consolidation    713xx
# 2   2       5000    36     17.97    12-2018  debt_consolidation    490xx
# 3   3       4000    36     18.94    12-2018  debt_consolidation    985xx
# 4   4      30000    60     16.14    12-2018  debt_consolidation    212xx
#
#   state  annual_inc home_ownership
# 0    NY       55000           RENT
# 1    LA       90000       MORTGAGE
# 2    MI       59280       MORTGAGE
# 3    WA       92000       MORTGAGE
# 4    MD       57250       MORTGAGE

# %% [markdown]
# ### Confirm data has been added by querying the state_data table

# %%
pd.read_sql_query('select * from state_data', con=engine).head()
# Out:
#         state abbreviation  population  average_income_2018  \
# 0     Alabama           AL      198218                49861
# 1      Alaska           AK       31275                74346
# 2     Arizona           AZ     1660272                59246
# 3    Arkansas           AR      193524                47062
# 4  California           CA      508529                75277
#
#    average_income_2017  average_income_2016  average_vantagescore  \
# 0                48123                46257                   654
# 1                73181                76440                   668
# 2                56581                53558                   669
# 3                45869                44334                   657
# 4                71805                67739                   680
#
#    average_credit_card_balance
# 0                         5961
# 1                         8516
# 2                         6389
# 3                         5660
# 4                         6481
